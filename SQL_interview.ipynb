# %% [markdown]
# # 1- What is the relational database management system?

# %% [markdown]
#  Relational database management system is a system that manage and organize in the form of tables with row and columns.
#
# RDBMS allowing for efficient retrival and data manupulation operation

# %% [markdown]
# # 2-What is sql?

# %% [markdown]
# Sql is a domain specific language used of managing and manupulating relation database management system.

# %% [markdown]
# # 3-What is a database?

# %% [markdown]
# Databasse is a organize collection of data stored and access electronically.

# %% [markdown]
# # 4- What is a primary key?

# %% [markdown]
# Primary key is a unique identifier for each record in a database table

# %% [markdown]
# # 5- What is a foreign key?

# %% [markdown]
# Foreign key is a key that link to the primary key in another table.
#
# establishing relationship between two table.

# %% [markdown]
# # 6- Explain between spreadsheet and database?

# %% [markdown]
# Spreadsheet managing iindividual dataset and database managing multiple datasets for efficient storage and retrieval.

# %% [markdown]
# # 7- What is a unique key?

# %% [markdown]
# Unique key is a column or set of columns in a database table the ensures each row have a distinct values preventing overfitting.

# %% [markdown]
# # 8- what is a table and field?

# %% [markdown]
# Table is a collection of data organize in a row and columns and field is a individual columns that store specific type of data in the database table.

# %% [markdown]
# # 9- Explain the various sql language?

# %% [markdown]
# there are three type of sql language
#
# 1- DDL(data definiation language) means define and manage database structure is known as data definition language.
#
# 2-DML(data manipulation language) retrieve and manipulate data in a database table.
#
# 3-DCL-(data control language) means control access and permission to the database.

# %% [markdown]
# # 10- What is a normalization?

# %% [markdown]
# Normalization is a process of organising data in a database table to reduce redundancy and improve data integrity.

# %% [markdown]
# # 11- What is a data integrity?

# %% [markdown]
# Data integrity ensures accuracy and consistency of data in a database table preventing error and mainten reliability.

# %% [markdown]
# # 12 What is a denormalization?

# %% [markdown]
# Denormalization is a process of intentionally introducing redundancy in a database table combining table to improve query performance.

# %% [markdown]
# # 13-Explain the different type of normalization?

# %% [markdown]
# 1NF- It hold only single value attribute,not hold multi value and composite attribute.
#
# single attribute means only hold single value.
#
# multi value attribute can hold multiple values in a single entity instance.
#
# composite attribute is combination of multiple values for example addresss is a combination of pinecode, state, country.

# %% [markdown]
# ![Normalisation_normalforms_1.jpg](attachment:c65edea7-349e-401a-a67e-13929c3f7dc9.jpg)

# %% [markdown]
# 2NF- means all non key attribute are fully functional dependent on primary key and eliminate partial dependancy on a composite key.

# %% [markdown]
# key attribute- key attribute a attrbute that identify unique record in a database table. for example student_id.
#
# non key attribute  is an attribute that can not identify unique record in a database table.
#
# composite attribute is an attribute that combine multiple attribute to identify unique record in a database table or composite key is a minimal set of key that identify unique record in a database table.
#
# when you use composite key in a table
#
# consider a scanario there is no available primary key in a table so in that case we take a set of attribute that can identify unique record in a table.

# %% [raw]
# STUD_NO            COURSE_NO        COURSE_FEE
# 1                     C1                  1000
# 2                     C2                  1500
# 1                     C4                  2000
# 4                     C3                  1000
# 4                     C1                  1000
# 2                     C5                  2000
# then decompose the table
#
#      Table 1                                    Table 2
# STUD_NO           COURSE_NO          COURSE_NO                COURSE_FEE
# 1                 C1                  C1                       1000
# 2                 C2                  C2                       1500
# 1                 C4                  C3                       1000
# 4                 C3                  C4                       2000
# 4                 C1                  C5                       2000
# 2                 C5

# %% [markdown]
# basic knowledge
#
# candidate key is minimal set of key that identify unique record in a database table.
#
# Superkey is not minimal set of key that identify unique record in a database table.
#
# for example suppose a database table attribute name employee_id, email_id,employee_name
#
# employee_id identify unique record in a database table it means employee_id is candidate key and employee_id and email_id is also identify each record
#
# in a database table means employee_id and email_id is a super key.
#
# prime attribue is part of candidate key.
#
# non prime attribute is not part of candidate key.

# %% [markdown]
# 3NF- Remove trransitive dependancy mean occurs when non prime attribute dependent on another non prime attribute is known as transitive dependancy means removing it.And all non prime attribute directly depend on primary key.

# %% [raw]
# emplyee_id employee_name  department supervisor_id
#
# 1            Alice         HR         101
# 2            Bob           IT         102
# 3            carol         HR         101
# 4            David         finance    103
#
# violate the third normal form then decompose the table
#
# employee_id employee_name supervisor_id
# 1            alice         101
# 2            Bob           102
# 3            carol         101
# 4             David        103
#
# another table
#
# supervisor_id  department
# 101             HR
# 102             IT
# 103             Finance

# %% [markdown]
# BCNF means all non key attrbute diractly dependent on primary key is known as BCNF.

# %% [markdown]
# 4NF remove the multi value dependancy.

# %% [raw]
# for example
#
# stud_id  course  hobbies
# 1        mathe    sing
# 1        science  son
# 2        chemistry play
# violet the 4th normal form
# then decompose the table
#
# stud_id  course
# 1        mathe
# 1       science
# 2       chemistry
#
# stud_id    hibbies
# 1           sing
# 1           song
# 2            play

# %% [markdown]
# 5NF-if there is no redundancy in a table then join the table.is known as 5th normal form.

# %% [markdown]
# sigle row function write single row at a time.
#
# multiple row write multiple row at a time.

# %% [markdown]
# union merge two table in a single table and omit duplicates.
#
# union all merage two table in a single table and not omit duplicates.

# %% [markdown]
# # 14-What is index?

# %% [markdown]
# Index in database are data structure that improve the speed of data retrieval operation in a database table.
#
# for example index in book which help to quickly locate information without having to scane the entire book.
#
# there are many types of index
#
# 1-single column index
#
# 2-composite index
#
# 3-unique index
#
# 4-clustered index
#
# 5-non clustered index
#
# 6-bitmap index

# %% [markdown]
# # 15- what is cursor?

# %% [markdown]
# Cursor is a database object to interact with database and used to traverse the result.

# %% [markdown]
# # 16-What is a query?

# %% [markdown]
# Query is request for information from a database.

# %% [markdown]
# # 17- What is a subquery?

# %% [markdown]
# Subquery is a query within another query used to retrieve data that will be used in main query.

# %% [raw]
# select product_name form product
# where categry_id=(select category_id from categories
# where category_name='electronics')
#
# Product table
# Product_name category_id
# Phone          101
# TV             101
# referigerator  101
#
#
# categories table
# category_id category_name
# 101         electronics

# %% [markdown]
# # 18-What is triggers?

# %% [markdown]
# Trigger is a set of instruction that automatically execute in response to the specific event.such as an update, delete and insert operation in a database.

# %% [markdown]
# # 19 What is a delete and truncate command?

# %% [markdown]
# When you need to remove specific rows base on a condition from database table then use delete operation.And when you want to remove all the row from database table without speciying condition the use truncate.
#
# or delete statement delete the specific row from the database table and truncate statement remove the entire row from the database table but both mainten the table structure.

# %% [markdown]
# # 20 What is local and global variable?

# %% [markdown]
# Local variable are declare within a function or specific blocks that accessible inside the function or specific blocks.
#
# Global variable decalre outside the function that accessible outside the function or outside the blocks.

# %% [markdown]
# # 21- What are the constarints?

# %% [markdown]
# Constraints help to prevents invalid and inconsistent data from being ineserted into the database.
#
# for example primary key constraints, foreign key constraints, not null constraints, distinct constraints, check constraints etc.

# %% [markdown]
# # 22- What is auto increament?

# %% [markdown]
# Auto increament is automatically generate and assign increamental values to the fields (basically a primary key) with each new record insertion.

# %% [raw]
# CREATE TABLE TABEL_1 ( ID INT AUTO_INCREAMENT,
#                         NAME VARCHAR(255),
#                         )
# INSERT INTO TABLE_1(NAME) VALUES('A')

# %% [markdown]
# # 23-What is data warehouse?

# %% [markdown]
# data warehouse is a central repository that store and integrate large valume of data from various sources.
#
# It is used for efficient analysis and reporting business intelligence purposes.

# %% [markdown]
# # 24 - Drop vs truncate statement?

# %% [markdown]
# When we use drop statement to delete the data and entire table structure and when we use truncate statement to delete all the data but retain the table structure.

# %% [markdown]
# # 25- What are aggregate and scalar function?

# %% [markdown]
# aggregate function perform operation on a multiple values and return single values for example sum, avg.
#
# select avg(salary) as avg_salary from employee_table
#
# scalar function perform operation on a single values and return modified or calcuated  values.
#
# select upper(first_name) as first_name from employee_table.

# %% [markdown]
# # 25 What is alias in sql?

# %% [markdown]
# Alias is a temporary name assigned to a table or column for the duration of the query.

# %% [markdown]
# select first_name  as firstName from employee.

# %% [markdown]
# #26- What is oltp and olap?

# %% [markdown]
# OLTP manage online transaction oriented task
#
# for example suppose customer place an order the system need to immediately response to the inventory to reflects changes in purchased items and process the transaction in the real time and chage the order status.

# %% [markdown]
# OLAP means online transactional processing to handle by handle by complex query and reporting for analysis of historical data.

# %% [markdown]
# # 27- What is a collation and various type of collaction sensitivity.

# %% [markdown]
# Collation determined the how the data stored and compared in a database.

# %% [markdown]
# case insensitive collation- consider lower and upper case are the same.
#
# case sensitive collaction - consider lower and upper case are the different.
#
# accent insensitive collation- ignoring the accent.
#
# accent sensitive- not ignoring the accent.

# %% [markdown]
# # 28 - How can we create table in sql ?

# %% [raw]
# 1- Inserting values into specific columns
#
# insert into employee(id,fist_name,last_name)
#
# values(1, 'sultan', 'ansari')
#
# 2- inserting into all columns
#
# insert into employee
#
# values(1,'sultan', 'ansari', 'student')
#
#
# 3- inserting data from another table
#
# - inser into new_table
# select * from old_table.
#
# -select into new_table
# from old_table.

# %% [markdown]
# # 29-How can we create table in sql?

# %% [markdown]
# create table table_name (id int , name varchar(200), ......)

# %% [markdown]
# # 30  how can we change the table name in sql?

# %% [markdown]
# using alter table
#
# alter table old_table_name rename to new_table_name

# %% [markdown]
# # 31 what is sql server?

# %% [markdown]
# sql server is a relational database management system used for storing and retrieving data as requested by other software application.

# %% [markdown]
# # 32- What is etl in sql?

# %% [markdown]
# ETL means extracting data from various sources and apply some tramsformation and the load to the target database.
#
# target database means where transform data are loaded.

# %% [markdown]
# # 33 - What are the nested query?

# %% [markdown]
# Nested query means query inside another query is know as nested query.

# %% [markdown]
# # Difference between subquery and nested query?

# %% [raw]
# Subquery directly contribute to the condition of the outer query.
#
# select student_name from students
# where grade=(select max(grade) from highest_grade_table)
#
# nested query does not directly contribute to the condition of the outer query.
#
# select student_name from student
# where student_id in ( select student_id from extra_curicular_activites
# where activity_type='sport')

# %% [markdown]
# # 34- what is differnece between char and varchar2 in datatypes in sql sever?

# %% [markdown]
# char is a fixed length datatypes and varchar is a variable length dataype in sql server and varchar2 used in mssql server.

# %% [markdown]
# # 35 What is the difference between sql and pl sql?

# %% [markdown]
# sql is a domain specific language used for relational database management system and pl sql is a procedural language used for allowing the creation of stored procedures.

# %% [markdown]
# # 36- what is the difference between sql and mysql?

# %% [markdown]
# sql is a domain specific language used for data retrieval and data manipulation operation.
#
# mysql is specific relational database management system.

# %% [markdown]
# # 37- What is the cross join ?

# %% [markdown]
# cartesian product of two table is known as cross join.

# %% [markdown]
# # 38- What are the user defined function?

# %% [markdown]
# User defined function is a function created by user in a programing or database environment.

# %% [raw]
# CREATE FUNCTION ADD_TWO_NO(@ NUM1 INT,@ NUM2 INT)
#                 RETURN INT
#                 AS
#                 BEGIN
#                   DECLARE @ RESULT INT,
#                   SET RESULT=@ NUM1+ @NUM2
#                   RETURN @ RESULT
#                 END
#
#                 CALL THE FUNCTION
#                 DECLARE @ SUM INT;
#                 SET @SUM=DBO.ADD_TWO_NUM(5,4);
#                 PRINT @ SUM---9

# %% [markdown]
# # 39 - What is clause?

# %% [markdown]
# clause is a syntatic units that represent a specific concepts within an statement.for example select class, orderby class, where class extra.

# %% [markdown]
# # 40 - What is the recursive stored procedure?

# %% [markdown]
# Recursive stored procedure is a database procedure that calls itself to perform repeatative task.

# %% [markdown]
# # 41- Explain UNION, MINUS and INTERACT commands?

# %% [markdown]
# Union merge the two table and omit the duplicates.
#
# minus return the result from the first query and not the second query.
#
# interact return the common recods from the both table.

# %% [markdown]
# # 44- What TCP/IP port does SQL Server run?

# %% [markdown]
# 1443

# %% [markdown]
# # 45 which operator used in query for pattern matching?

# %% [markdown]
# like operator is used in query for pattern matching.
#
# select * from employees
#
# where  first_name like 'a%';
#
# first name start a character,

# %% [markdown]
# # 46 - who can we select unique record from a table?

# %% [markdown]
# using distinct to select unique record from a table.

# %% [raw]
# select distinct countory from customers;

# %% [markdown]
# # 47 -  List and explain each of the ACID properties that collectively guarantee that database transactions are processed reliably?

# %% [raw]
# Atomicity means transaction are treated single individual units either fully rollback or fully completed.
#
# for example suppose a transaction money from one bank account to the another bank account.The transaction invloves two steps deducting mony from souce account and crediting to the destination account.
#
# atomicity ensures that both transaction are successfully completed leaving the account in the consistent state.
# suppose a transaction are source account is successfullly completed but crediting to the destinatio account is to fail mean both entire transaction will be rollback.both account will remain in their consistent state preserving the data integrity overall performance.
#
#
# Consistency means gaurantee the the transaction bring the database from one valid state to another.
#
#
# Isolation maintening the transaction independance means execuation of multiple transaction concurrently does not inteace each othe.
#
# Durability- gaurantee that once a transaction is commited its effects are premanent the survive any subsquent system failures or crashes.

# %% [markdown]
# # 48 - what is the main difference in the between and in conditional operators?

# %% [markdown]
# between operator used to filters result within the specific range.
#
# select * from employees where salary between 1000 to 5000;
#
# in operator used to filters result based on the specific values.
#
# select * from products where category in ('electronics', 'books');

# %% [markdown]
# # 49- what are sql function  used for ?

# %% [markdown]
# sql function are used to perform operation on a data returning result based on the input values or expression.

# %% [markdown]
# # 50 . What is the need for MERGE statement?

# %% [markdown]
# Merge statement is needed to perform conditional insert, update and delete operation in the single line sql statement.

# %% [markdown]
# # 51-  List the ways in which dynamic SQL can be executed?

# %% [markdown]
# using execute statement , database specific spi, orm or onject relational mapper and stored procedure through dynamics sql can be executed.

# %% [markdown]
# # 52- list some case manipulation function in sql?

# %% [markdown]
# INITCAP, LOWER, UPPAR ETC

# %% [markdown]
# # 54- Is semicolon used after sql? Justify why or why not.

# %% [markdown]
# semicolon is used after the sql statement and seperate multiple statement in a batch.

# %% [markdown]
# # 55-What is the difference between JOIN and UNION?

# %% [markdown]
# joins combines the columns based on the related columns from the both table.
#
# unions combines the uniques row from the two tables.

# %% [markdown]
# # 56 -What is the difference between order and group by?

# %% [markdown]
# order by the result based on the specific column either descending or ascending.
#
# gruop by group the rows that have a same values in a specific columns.

# %% [markdown]
# # 57- What is SQL injection? When does SQL injection occur?

# %% [markdown]
# sql injection is a malicious techniques where an attacker attack insert or manipulate sql query in the input field.
#
# using sql ingestion to use unauthorized access of database.

# %% [markdown]
# # 58- what is a enum?

# %% [markdown]
# enum is a set of data types that defined set of the possible values for a columns.

# %% [raw]
# create table_1 (id int, name varchar(1000), priority enum(low, medium, high, not null);

# %% [markdown]
# # 59- What is difference between atan and atan2?

# %% [markdown]
# atan return the arc tanget of number
#
# and atan2 retuan the arc tangent of quotient.

# %% [markdown]
# # 60- what is  difference beteen ceil, floor and round function?

# %% [markdown]
# ceil function return up to the nearest values.
# ceil(3.6)=4
#
# floor function return round down to the nearest values.
# floor(2.6)=2
#
# round function return round to the neatest integers.
# round(2.6)=3,
# round(2.4)=2

# %% [markdown]
# # 61- . What is the RAND() function?

# %% [markdown]
# round function return the round to the nearest values
# the value belong to 0 to 1 , 1 is excluded.

# %% [markdown]
# # 62-  What is the difference between LOCALTIMESTAMP and CURRENT_TIMESTAMP?

# %% [markdown]
# The CURRENT_TIMESTAMP retrieves the date and time along with the time zone,
#
# while the LOCALTIMESTAMP function retrieves the date and time without the time zone.
#
# return a timestamp with time zone and return the timestamp without time zone.

# %% [raw]
# SELECT LOCALTIMESTAMP();
#
# SELECT CURRENT_TIMESTAMP();

# %% [markdown]
# # 63- Name three functions that specify current date and time?

# %% [raw]
# SELECT CURRENT_TIMESTAMP AS CURRENT_DATA_TIME;
#
# SELECT CURRENT_DATE AS CURRENTDATE;
#
# SELECT NOW() AS CURRENT_DATE_TIME;

# %% [markdown]
# # 64- Which function returns the difference between two periods? What would the format of the output be?

# %% [raw]
# DATEDIFF('DAY', '2023-10-01','2023-01-10')

# %% [markdown]
# # 66-How can we fetch alternate records from a table?

# %% [raw]
# SELECT * FROM( SELECT EMPLOYEE.*,
#               ROW_NUMBER() OVER (ORDER BY SALARY) AS ROW_NUM
#               FROM EMPLOYEES
#              ) AS T
#            WHERE T.ROW_NUM%2=1

# %% [markdown]
# # 66-How can we fetch common records from two tables?

# %% [markdown]
# USING INNER JOIN TO FETCH COMMON RECORD FROM TWO TABLE.

# %% [markdown]
# # 67- What is the command used to fetch the first 5 characters of the string?

# %% [markdown]
# SELECT SUBSTRING(COLUMN_NAME, START, END) AS FIRST_FIVE_CHARACTER;

# %% [markdown]
# # 68- How to use like statement is sql?

# %% [markdown]
# like statement is used in where class to search for aspecific person in a columns.

# %% [markdown]
# # 69- How can we copy a table in SQL?

# %% [raw]
# INSERT INTO NEW_TABLE
# SELECT * FROM OLD_TABLE;

# %% [markdown]
# # 70- If we drop a table, does it also drop related objects?

# %% [markdown]
# Does not dropping the related objects such as trigger, index and constraints.

# %% [markdown]
# # 71- what is a live lock?

# %% [markdown]
# live lock occurs when two or more process contineusly change their state in response to the other state changebut resulting in no progress.
# for example two people try to  passs each other in moving corridor but repeatedly moving in the same direction to let the pass other.

# %% [markdown]
# # 72- Can you join a table by itself?

# %% [markdown]
# yes

# %% [markdown]
# # 73- Explain Equi join with an example.

# %% [markdown]
# equi joins means join a two table based on the specific condition for example equal.

# %% [markdown]
# # 74 Explain non Equi join with an example?

# %% [markdown]
# non equi join means join a two table based on the specific condition <,>, <=, >= etc.

# %% [markdown]
# # 75- State the difference between NVL and NVL2 functions?

# %% [markdown]
# nvl if then return repace values otherwise return actual values
#
# select coalesce( column_name, replaced_values) from table_1;
#
# nvl2 if the column contains not null values means return not null values otherwiese null values.

# %% [raw]
# select
# case
#   when column is not null then "not null values"
# else "null values"
# end
# from table_1;

# %% [markdown]
# # 76- Where is MyISAM table stored?

# %% [markdown]
# MYISAM table in mysql are stored in disk file.MYD extension.

# %% [markdown]
# # 77- What does myisamchk do?

# %% [markdown]
# when we myisam table any problem face then use myisamchk do.

# %% [markdown]
# # 78- How can we store videos inside SQL server table?

# %% [markdown]
# to provide video_id, video_name and file_path to stored video in mysql server.

# %% [markdown]
# # 79-Write an SQL query to show the second highest salary from a table.

# %% [raw]
# select max(salary) from employees
# where salary < (select max(salary) from employees);

# %% [markdown]
# # 80- Write an SQL query to fetch three max salaries from a table?

# %% [raw]
# select max(salary) as three_max_salary from employees limit 3;

# %% [markdown]
# # 81-  What are the differences between the HAVING clause, and the WHERE clause?

# %% [markdown]
# where clause filter the individual row before they are grouped.
#
# having clause filter the grouped row after the aggregating.

# %% [markdown]
# # 82- What does a BCP command do?

# %% [markdown]
# BCP means bulk copy program is a sql server command is used to bulk data import or export between files and sql server table.

# %% [markdown]
# # 83- Can a view be active if the base table is dropped?

# %% [markdown]
# not view is active because view is a virtual table.

# %% [markdown]
# # 84-When should we use NoSQL and SQL?

# %% [markdown]
# sir,the choice depends on the specific need of the project.
#
# suppose a data organize in a structure manner and require more consistency then use sql.
#
# suppose a data organized in unstructure way the use non sql.

# %% [markdown]
# # 85- What is SYSTEM privilege?

# %% [markdown]
# Sytem privillage in database grant a user the highest level of the administrative access allowing them to perform any action.
#
# for example grant a system to the user name.
#
# Object privillage in database control access to the specific database objects. for example table, view.

# %% [markdown]
# # 88-Does the data stored in the stored procedure increase access time or execution time? Explain.

# %% [markdown]
# the stored in the stored procedure does not increase the access time and execution time it is precompiled and optimized for faster execution.

# %% [markdown]
# # 89- . What is CTE?

# %% [raw]
# WITH DEPARTMENT_CTE AS (
#          SELECT DEPARTMENT_ID,
#          COUNT(*) AS DEP_EMP_COUNT,
#          GROUP BY DEPARTMENT_ID);
# SELECT * FROM DEPARTMENT_CTE;

# %% [markdown]
# CTE is a (comman table expression) temparary result set in a select statement enhancing, readability,simplicity and complex queries.

# %% [markdown]
# # 90- . Does view contain data?

# %% [markdown]
# No ,because view is a virtual table.

# %% [markdown]
# # 91- Define a temp table?

# %% [markdown]
# Temp table mean that exist temparary and stored immediatly result during the execution of the query.

# %% [markdown]
# # 92-  What is the difference between the RANK() and DENSE_RANK() function?

# %% [raw]
# Rank() assign a non consecutive rank to tied values without gaps.
# select stud_id,
#          score,
#          rank() over(order by score desc) as ranked
#          from score;

# %% [raw]
# stud_id   score          stud_id   score    ranked
# 1          90               3       92        1
# 2          85               1       90        2
# 3          92               4       90        2
# 4          90               2       85        4
# 5          85               5       85        4

# %% [raw]
#  Dense Rank() assign consecutive rank to tied values without gaps.
#
#  select stud_id,
#         score
#         dense_rank over(order by score desc)
#         from scores;
#
#
#
#
# stud_id    score    ranked
# 3           92        1
# 1           90        2
# 4           90        2
# 2           85        3
# 5           85        3

# %% [markdown]
# # 93-What is referential integrity?

# %% [raw]
# Referential integrity provide a relationship between two table reamins consistent.
#
#
# for example forign key value in one table correspond to primary key value in another table.
#
# CREATE TABLE ORDERS(
#              ORDER_ID INT PRIMARY_KEY,
#              ORDER_NO INT,
#              CUSTOMER_ID INT,
#              FOREIGN_KEY (CUSTOMER_ID) REFERENCES (CUSTOMER(CUSTOMER_ID)
#              );

# %% [markdown]
# # 94- What are nested triggers?

# %% [markdown]
# NESTED TRIGGER means one trigger inside another is a set of instruction that automatically execute in response to the specific event such an  insert, update and delete operation in a database.

# %% [markdown]
# # 95-  What is schema in SQL server?

# %% [markdown]
# Schema is a container for the database object such a table, view provide a way to organise and manage those objects within the database.

# %% [markdown]
# # 96- Write a query to fetch 50% records from an EmployeeInfo table?

# %% [raw]
# SELECT * FROM EMPLOYEES
#    LINNIT (SELECT COUNT(*)/2 FROM EMPLOYEES);

# %% [markdown]
# # 97- Write a query to fetch all the record?

# %% [raw]
# select * from employees
# limit n or 10;

# %% [markdown]
# # 98- What is CTE in SQL server?

# %% [markdown]
# cte in sql sever is a result set in a select statemant enhancing, readability, simplicity and complex query.

# %% [markdown]
# # 99- What is view?

# %% [markdown]
# View is a virtual table.
#
# That provide a way to complex query and control access to the underlying data.

# %% [markdown]
# # 100 - what is join and types?

# %% [markdown]
# join means combines record based on the related columns from the two or more tables.

# %% [markdown]
# 1- Inner join- We can use inner join extract the record from two or more table based on the related columns.

# %% [markdown]
# 2- Left join-return all of the records where the two table have matching entries along with all of the record in the left columns.

# %% [markdown]
# 3-Right join- return all of the records where the two table have matching entries along with all of the records in the right columns.

# %% [markdown]
# 4- Outer join- return all of the records from the both tables.

# %% [raw]
# SELECT Customers.customer_id, Customers.first_name, Orders.amount
# FROM Customers
# JOIN Orders
# ON Customers.customer_id = Orders.customer;

# %% [markdown]
# # 101-what is serrogate key

# %% [markdown]
# serrogate key is also called a syntatic primary key when a new record is inserted into table automatically by database.

# %% [markdown]
# primary  key-- fact----slower query---natural key
#
# serrogate key---factles---faster---anonomyous integer
#
# It is automatically generated by the system.
#
# It holds an anonymous integer.
#
# It contains a unique value for all records of the table.
#
# The value can never be modified by the user or application.
#
# The surrogate key is called the factless key as it is added just for our ease of identification of unique values and contains no relevant
# fact(or information) that is useful for the table.

# %% [markdown]
# # 102 - what is minimal key?

# %% [markdown]
# Minimal key means smallest set of attribute that identify uniquely each records of the table
